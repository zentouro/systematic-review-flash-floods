# %%
import numpy as np
import pandas as pd

# %%
# !pip install doi2bib
# Out:
# Collecting doi2bib
#   Downloading doi2bib-0.4.0-py3-none-any.whl (6.0 kB)
# Requirement already satisfied: future in /opt/miniconda3/envs/cmip6-env/lib/python3.9/site-packages (from doi2bib) (0.18.2)
# Collecting bibtexparser
#   Downloading bibtexparser-1.2.0.tar.gz (46 kB)
#      |████████████████████████████████| 46 kB 3.2 MB/s eta 0:00:01
# Requirement already satisfied: requests in /opt/miniconda3/envs/cmip6-env/lib/python3.9/site-packages (from doi2bib) (2.25.1)
# Requirement already satisfied: pyparsing>=2.0.3 in /opt/miniconda3/envs/cmip6-env/lib/python3.9/site-packages (from bibtexparser->doi2bib) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/cmip6-env/lib/python3.9/site-packages (from requests->doi2bib) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /opt/miniconda3/envs/cmip6-env/lib/python3.9/site-packages (from requests->doi2bib) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/miniconda3/envs/cmip6-env/lib/python3.9/site-packages (from requests->doi2bib) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/miniconda3/envs/cmip6-env/lib/python3.9/site-packages (from requests->doi2bib) (3.0.4)
# Building wheels for collected packages: bibtexparser
#   Building wheel for bibtexparser (setup.py) ... done
#   Created wheel for bibtexparser: filename=bibtexparser-1.2.0-py3-none-any.whl size=36712 sha256=da67ba5b3e92d43ce28ffffb0dc01c7916867a62923e72db3c5c1cecc9d021de
#   Stored in directory: /Users/miriam/Library/Caches/pip/wheels/8d/7a/34/56413b9ab410bb24cf1403d9165f7a97d4c0e938773b8ee86d
# Successfully built bibtexparser
# Installing collected packages: bibtexparser, doi2bib
# Successfully installed bibtexparser-1.2.0 doi2bib-0.4.0

# %%
import doi2bib

# %%
data = pd.read_csv('./ScreenedData_for-visulization.csv')

# Drop columns we don't need
data.drop(['Key', 'DT2', 'TC', 'PA', 'CR', 'C1', 'SR', 'BE', 'FU', 'BN', 'SN', 'PN', 'PP', 
           'PU', 'VL', 'UT', 'NR', 'SC', 'U2', 'WC', 'EM', 'SE', 'GA', 'BO', 'RP', 'DB', 
           'AU_UN_NR', 'AU_UN', 'SR_FULL','About an actual event',  'Screen3_Planning', 
           'DT', 'LA', 'SO', 'DE', 'ID', 'AU1_UN'], axis=1, inplace=True)

data.rename(columns = {'Study method':'methods', 
                       'After a flood': 'impacts', 
                       'Paper framing': 'framing', 
                       'Meta topic': 'meta_topic',
                       'Before a flood': 'before',
                       'During a flood': 'during',
                       'Urban/Rural': 'urban_rural',
                       'Flood type': 'flood_type',
                       'DI': "DOI"
                      }, inplace = True)

data.head()
# Out:
#                                AU  \
# 0        Rajesh S;Jain S;Sharma P
# 1             Bergholt D;Lujala P
# 2           Nyaupane Gp;Chhetri N
# 3         Mcclelland Dm;Bowles Ds
# 4  Soon Nk;Isah N;Ali Mb;Ahmad Ar
#
#                                                   TI  \
# 0  Inherent vulnerability assessment of rural hou...
# 1  Climate-related natural disasters, economic gr...
# 2  Vulnerability to climate change of nature-base...
# 3  Estimating life loss for dam safety and risk a...
# 4  Effects of smart tunnel maintenance works on f...
#
#                                                   AB  \
# 0  The recent trend of shifting focus from hazard...
# 1  Global warming is expected to make the climate...
# 2  Given their unique natural attractions, includ...
# 3  An understanding of life-loss dynamics associa...
# 4  Smart was the light in the tunnel to end devas...
#
#                              DOI      PY meta_topic  framing before  during  \
# 0  10.1016/J.ECOLIND.2017.10.014  2018.0          0        2      0       0
# 1       10.1177/0022343311426167  2012.0          1        0      0       0
# 2      10.1080/14616680802643359  2009.0          1        0      0       0
# 3                            NaN  2000.0          6        1      0       0
# 4          10.1166/ASL.2017.7172  2017.0          6        0      0       0
#
#   impacts methods urban_rural flood_type
# 0       2  6_9_11           0          1
# 1     2_7   11_13           0          1
# 2     2_7       9           2        5_8
# 3       1       9           0          3
# 4       0  6_8_11           0          1

# %% [markdown]
# Simple bib

# %% [markdown]
# More Complex bib
